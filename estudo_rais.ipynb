# %%
import pandas as pd
import numpy as np

# %%
df_2017 = pd.read_csv(r'C:\Users\Eduardo\Documents\Facul\Economia Regional e Urbana\base de dados\csv\RAIS_Micro_PR_CNAE2.0_2017.csv', sep=';',encoding='latin1')

# %%
coluns = df_2017.columns[1:40]
df= []
for i in coluns:
    df.append(df_2017[i].divide(df_2017['Total']))
df = pd.DataFrame(df).T
df.columns = coluns
df.insert(0,"setor",df_2017["SETOR"])

# %%
df_2017
# Out:
#                                                 SETOR  PARANAVAÍ  UMUARAMA  \
# 0       AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS       7540      3454
# 1                                  PRODUÇÃO FLORESTAL         38        69
# 2                                 PESCA E AQÜICULTURA          9         7
# 3                          EXTRAÇÃO DE CARVÃO MINERAL          0         0
# 4                  EXTRAÇÃO DE PETRÓLEO E GÁS NATURAL          0         0
# ..                                                ...        ...       ...
# 84             OUTRAS ATIVIDADES DE SERVIÇOS PESSOAIS        123       217
# 85                                SERVIÇOS DOMÉSTICOS          4        10
# 86  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...          0         0
# 87                                          {ñ class}          0         0
# 88                                              Total      62202     59469
#
# ...
